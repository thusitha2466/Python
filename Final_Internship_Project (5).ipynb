# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b71cd3a5-90ec-49f8-9560-6085f34b6310" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b71cd3a5-90ec-49f8-9560-6085f34b6310">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("student_performance_dataset_1000_rows.csv")

# %% [markdown]
# python

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-2d3d02bd-8f4d-47a7-972b-811965627e5b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2d3d02bd-8f4d-47a7-972b-811965627e5b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# df

# %%
import pandas as pd

df = pd.read_csv("student_performance_dataset_1000_rows.csv")

print("Total Rows:", len(df))
print("Total Columns:", len(df.columns))

pd.set_option('display.max_rows', None)

display(df)
# Out:
# Total Rows: 1000
# Total Columns: 11
#     StudentID   StudentName  Class  Tamil  English  Mathematics  Science  \
# 0     STU0001     Student_1  CSE-B     49       38           70       66
# 1     STU0002     Student_2  CSE-A     48       46           89       39
# 2     STU0003     Student_3  ECE-A     62       64           99       38
# 3     STU0004     Student_4  ECE-A     63       92           70       35
# 4     STU0005     Student_5  CSE-A     78       70           54       62
# 5     STU0006     Student_6   IT-A     46       83           47       80
# 6     STU0007     Student_7   IT-A     40       93           50       83
# 7     STU0008     Student_8   IT-A     81       59           43       40
# 8     STU0009     Student_9  ECE-A     45       64           47       83
# 9     STU0010    Student_10   IT-A     81       55           82       80
# 10    STU0011    Student_11  ECE-A     44       56           66       55
# ...

# %%
grade_a_students = df[df['Grade'] == 'A']

print("Total Grade A Students:", len(grade_a_students))
print(grade_a_students.head(10))
# Out:
# Total Grade A Students: 78
#     StudentID  StudentName  Class  Tamil  English  Mathematics  Science  \
# 37    STU0038   Student_38  CSE-B     93       71           89       97
# 67    STU0068   Student_68  ECE-A     61       90           76       94
# 74    STU0075   Student_75  ECE-A     93       52           94       75
# 75    STU0076   Student_76  CSE-B     92       55           95       92
# 95    STU0096   Student_96  CSE-B     97       48           90       81
# 96    STU0097   Student_97  ECE-A     90       57           69       96
# 101   STU0102  Student_102  ECE-A     65       87           97       65
# 121   STU0122  Student_122  ECE-A     73       86           69       99
# 124   STU0125  Student_125  ECE-A     95       91           70       58
# 134   STU0135  Student_135  CSE-B     88       96           95       66
#
#      Computer  Average Grade Pass_Fail
# 37         54     80.8     A      Pass
# 67         91     82.4     A      Pass
# ...

# %%
pass_students = df[df['Pass_Fail'] == 'Pass']

print("Total Pass Students:", len(pass_students))
print(pass_students.head(10))
# Out:
# Total Pass Students: 700
#    StudentID StudentName  Class  Tamil  English  Mathematics  Science  \
# 4    STU0005   Student_5  CSE-A     78       70           54       62
# 5    STU0006   Student_6   IT-A     46       83           47       80
# 6    STU0007   Student_7   IT-A     40       93           50       83
# 7    STU0008   Student_8   IT-A     81       59           43       40
# 8    STU0009   Student_9  ECE-A     45       64           47       83
# 9    STU0010  Student_10   IT-A     81       55           82       80
# 10   STU0011  Student_11  ECE-A     44       56           66       55
# 11   STU0012  Student_12  CSE-A     69       63           76       42
# 12   STU0013  Student_13   IT-A     75       86           69       43
# 13   STU0014  Student_14   IT-A     62       98           85       93
#
#     Computer  Average Grade Pass_Fail
# 4         78     68.4     C      Pass
# 5         79     67.0     C      Pass
# 6         45     62.2     C      Pass
# ...

# %%
print(df['Grade'].value_counts())
# Out:
# Grade
# C     408
# B     313
# D     178
# A      78
# F      17
# A+      6
# Name: count, dtype: int64

# %%
print("Average Marks:", df['Average'].mean())
# Out:
# Average Marks: 67.62120000000002

# %%
top10 = df.sort_values(by='Average', ascending=False)
print(top10.head(10))
# Out:
#     StudentID  StudentName  Class  Tamil  English  Mathematics  Science  \
# 630   STU0631  Student_631  CSE-A     82      100          100       92
# 293   STU0294  Student_294  CSE-A     99      100           97       73
# 282   STU0283  Student_283  ECE-A     98      100           94       98
# 899   STU0900  Student_900  ECE-A     95       93          100       95
# 195   STU0196  Student_196   IT-A     91       89           97       91
# 490   STU0491  Student_491   IT-A     80       96           97       79
# 721   STU0722  Student_722  CSE-A     80       76          100       97
# 663   STU0664  Student_664  CSE-A     86       80           79       97
# 134   STU0135  Student_135  CSE-B     88       96           95       66
# 651   STU0652  Student_652  CSE-A     94       92           80       74
#
#      Computer  Average Grade Pass_Fail
# 630        97     94.2    A+      Pass
# 293        95     92.8    A+      Pass
# 282        74     92.8    A+      Pass
# ...

# %%
import matplotlib.pyplot as plt

df['Grade'].value_counts().plot(kind='bar')

plt.title("Grade Distribution")
plt.xlabel("Grade")
plt.ylabel("Number of Students")
plt.show()

# %% [markdown]
# Pie Chart-Pass vs Fail Analysis

# %%
import matplotlib.pyplot as plt

df['Pass_Fail'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%'
)

plt.title("Pass vs Fail Distribution")
plt.ylabel("")
plt.show()

# %%
subjects = ['Tamil','English','Mathematics','Science']

print(df[subjects].mean())
# Out:
# Tamil          67.803
# English        67.118
# Mathematics    68.965
# Science        67.303
# dtype: float64

# %% [markdown]
# Bar Chart-Subject Wise Average Marks

# %%
import matplotlib.pyplot as plt

df[subjects].mean().plot(kind='bar')

plt.title("Subject Wise Average Marks")
plt.xlabel("Subjects")
plt.ylabel("Average Marks")
plt.show()

# %%
(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   StudentID    1000 non-null   object
#  1   StudentName  1000 non-null   object
#  2   Class        1000 non-null   object
#  3   Tamil        1000 non-null   int64
#  4   English      1000 non-null   int64
#  5   Mathematics  1000 non-null   int64
#  6   Science      1000 non-null   int64
#  7   Computer     1000 non-null   int64
#  8   Average      1000 non-null   float64
#  9   Grade        1000 non-null   object
#  10  Pass_Fail    1000 non-null   object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 86.1+ KB

# %%
display(df.isnull().sum().to_frame(name="Null Count"))
# Out:
#              Null Count
# StudentID             0
# StudentName           0
# Class                 0
# Tamil                 0
# English               0
# Mathematics           0
# Science               0
# Computer              0
# Average               0
# Grade                 0
# Pass_Fail             0
# Total                 0

# %% [markdown]
# Null Value Check

# %%
df.isnull().sum()
# Out:
# StudentID      0
# StudentName    0
# Class          0
# Tamil          0
# English        0
# Mathematics    0
# Science        0
# Computer       0
# Average        0
# Grade          0
# Pass_Fail      0
# Total          0
# dtype: int64

# %% [markdown]
# Total Marks Calculation

# %%
subjects = ['Tamil','English','Mathematics','Science','Computer']
df['Total'] = df[subjects].sum(axis=1)

df[['StudentName','Total']].head()
# Out:
#   StudentName  Total
# 0   Student_1    286
# 1   Student_2    260
# 2   Student_3    323
# 3   Student_4    315
# 4   Student_5    342

# %% [markdown]
# Average Marks Calculation

# %%
df['Average']=df[subjects].mean(axis=1)
df[['StudentName','Average']].head(7)
# Out:
#   StudentName  Average
# 0   Student_1     57.2
# 1   Student_2     52.0
# 2   Student_3     64.6
# 3   Student_4     63.0
# 4   Student_5     68.4
# 5   Student_6     67.0
# 6   Student_7     62.2

# %% [markdown]
# Grade Assignment Output

# %%
def grade(avg):
    if avg >= 90:
        return 'A+'
    elif avg >= 80:
        return 'A'
    elif avg >= 70:
        return 'B'
    elif avg >= 60:
        return 'C'
    elif avg >= 50:
        return 'D'
    else:
        return 'F'

df['Grade'] = df['Average'].apply(grade)
df[['StudentName', 'Average', 'Grade']].tail()
# Out:
#       StudentName  Average Grade
# 995   Student_996     83.0     A
# 996   Student_997     70.8     B
# 997   Student_998     62.0     C
# 998   Student_999     60.6     C
# 999  Student_1000     60.8     C

# %% [markdown]
# Subject-wise Average Marks

# %%
df[subjects].mean()
# Out:
# Tamil          67.803
# English        67.118
# Mathematics    68.965
# Science        67.303
# Computer       66.917
# dtype: float64

# %% [markdown]
# Highest Marks in Each Subject

# %%
df[subjects].max()
# Out:
# Tamil          100
# English        100
# Mathematics    100
# Science        100
# Computer       100
# dtype: int64

# %% [markdown]
# Lowest Marks in Each Subject

# %%
df[subjects].min()
# Out:
# Tamil          35
# English        35
# Mathematics    35
# Science        35
# Computer       35
# dtype: int64

# %% [markdown]
# Students Scoring Above 90 in Maths

# %%
df[df['Mathematics']>90]
# Out:
#     StudentID  StudentName  Class  Tamil  English  Mathematics  Science  \
# 2     STU0003    Student_3  ECE-A     62       64           99       38
# 15    STU0016   Student_16  CSE-A     63       52          100       98
# 19    STU0020   Student_20  CSE-A     35       68           99       57
# 21    STU0022   Student_22   IT-A     35       76           97       37
# 25    STU0026   Student_26  CSE-B     82       91           92       50
# 35    STU0036   Student_36  ECE-A     56       87           97       96
# 39    STU0040   Student_40  CSE-A     41       96           99       55
# 57    STU0058   Student_58  CSE-B     63       60           93       79
# 64    STU0065   Student_65   IT-A     50       73           99       74
# 68    STU0069   Student_69   IT-A     62      100           95       56
# 73    STU0074   Student_74  CSE-A     63       57           94       41
# 74    STU0075   Student_75  ECE-A     93       52           94       75
# ...
